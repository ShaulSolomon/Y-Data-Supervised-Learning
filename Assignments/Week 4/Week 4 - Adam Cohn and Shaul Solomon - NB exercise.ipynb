# %% [markdown]
# import pandas as pd
# # ^^^ pyforest auto-imports - don't write above this line
# # Naive Bayes

# %% [markdown]
# ## 1. Classifying Digits
# In this part we will test digits classification on the MNIST dataset, using Bernoulli Naive Bayes (a generative model), in contrast to the Multivariate Logistic Regression (a discriminative model) we used before.
#
# The MNIST dataset contains 28x28 grayscale images of handwritten digits between 0 and 9 (10 classes). For mathmatical analysis clarity, and for matching expected API, each image faltten to create a 1D array with 784 elements.

# %% [markdown]
# ### Loading the MNIST dataset
# Load the MNIST data set. The digits dataset is one of datasets scikit-learn comes with that do not require the downloading of any file from some external website. Use
# >```
# mnist = sklearn.datasets.fetch_mldata('MNIST original')
# ```
#
# to fetch the original data. You may set the `data_home` to where you wish to download your data for caching. Each image is already transformed into a 1D integer array $x\in [0,255]^{784}$, and the corresponding label is an integer $y\in [0,9]$.
#
# Plot a single sample of each digit as the original image, so you get a feeling how the data looks like.
#
# Finally, divide your data into train and test sets, using 1/7 of the data for testing.
#
# ---
# **Note 1:** Using `digits = sklearn.datasets.load_digits()` will only fetch a very small sample of the original set, with images resized to 8x8. This preprocessing of the data reduces dimensionality and gives invariance to small distortions - however, we will use the original data in this exercise. Feel free to test the proformance of the algorithms below on the preprocessed data as well.
#
# **Note 2:**
# Since ML-Data is deprecated, you may wish to use something like this:
# >```
# from keras.datasets import mnist
# (x_train, y_train), (x_test, y_test) = mnist.load_data()
# x_train = x_train.reshape(x_train.shape[0], 784)
# x_test = x_test.reshape(x_test.shape[0], 784)
#   ```

# %%
import sklearn
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Bernoulli Naive Bayes
# If we know how the digits are generated, then we know how to classify them (simply choose the digit class which will maximize the posterior probability) --- but which model should we use for describing the digits generation?
#
# In this part we will try a very simplified model of digits creation (which is obviously not the same as the "real" model), using a Naive Bayes over an underlying Bernoulli distribution --- that is, we will assume that given a digit class, the pixels of the images are the result of independent coin flips, each with its own "head" probability.
#
# Note that since we assume each pixl is either 0 (black) or 1 (white), we will need to adjust (preprocess) our data accrodingly (see below).
#
# So, the model is stated as follows:
# $$
# \begin{align}
# \text{Domain} && x \in \{0,1\}^{784} \\
# \text{Prior} && \pi_j = \Pr(y=j) \\
# \text{Likelihood} && P_j(x) = \Pr(x | y=j) \\
# \end{align}
# $$
#
# Where for each $i\in 0\ldots 784$ it holds that
# $$
# P_{ji}(x_i) = \Pr(x_i | y=j) =
# \begin{cases}
# p_{ji} & \text{if } x_i=1 \\
# 1-p_{ji} & \text{if } x_i=0 \\
# \end{cases}
# $$

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 784)
X_test = X_test.reshape(X_test.shape[0], 784)

# %% [markdown]
# #### Question 1
# Write the classification rule based on this Naive Bayes model.
# How would you esitmate each of the parameters of the model based on the trainning data?
#
#
# **Bonus:** Think of edge cases which may effect your estimator in an undesired way.

# %% [markdown]
# #### Answer 1
# P(y|x) = P(x|y)P(y) = likelihood * prior
#
# Prior - For each class `i`, just get the number of X_train samples that are of class `i`.<br>
# Likelihood - For each of the 784 pixels, we get for each class `i` - how many times there is a 1 divided by the total number of train samples. So for example, if on the the `jth` pixel, there are 300 times that there is a 1 for class `i`, and there are 70000 total examples, so then the P(x_j | y_i) = (300/70000) + (69700/70000) = xi * log(p_ji) + (1 - xi) * log(1 - p_ji)
#
#
# Because there will be many pixels for every class where none of them will be 1,especially at the literal edges of the images, we will need to use laplacian smoothing.
#
# **Edge Case** - When we have for example a 'One', but it is usually located on the left side of the image, but we have several on the right side of the image. Because the Naive Bayes is only calculating the likelihood pixel by pixel, it will affect the estimator because it will assign likelihoods to regions unfairly and mess up our general model. As long as the edge cases are minimal, it shouldnt cause too much of an issue, especially if our general train data is large.

# %% [markdown]
# #### Question 2
# Run a Naive Bayes classifier on the training data and apply predictions on the test data. Use the [sklearn.naive_bayes.BernoulliNB](http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.BernoulliNB.html) implementation (see the [source code for sklearn.naive_bayes](https://github.com/scikit-learn/scikit-learn/blob/master/sklearn/naive_bayes.py) for details).
#
# Remember we need to preprocess the data in this case such that each pixel would become either black (0) or white (1). For this, use the `binarize` parameter of the implementation. Set this value to $0$ (this is the default), which in this case would mean every pixel with non-zero value will be set to 1.
#
# 1. Plot the mean image of each class (estimated $\hat{p}_{ji}$) and generate one sample of each class (remember, you can do this since this is a generative model). You will need to access the `feature_log_prob_` attribute of the trained model.
#
# 2. Plot the confusion matrix of your classifier, as claculated on the test data (it is recommended to use [sklearn.metrics.confusion_matrix](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html)). Calculate the total accuracy (fraction of correctly classified images), and summarize the results in your own words.
#
# 3. Think of a way you can find the optimal threshold of the binarization part. **There is no need to actually perform this task --- just describe what you would have done.**

# %% [markdown]
# #### Answer 2
# Put you answer here...

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
clf = BernoulliNB(binarize=0).fit(X_train, y_train)

# %%
for i in clf.classes_:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,6))
    fig.suptitle("Class: {}".format(i))
    ax1.imshow(clf.feature_log_prob_[int(i)].reshape(28,28));
    ax1.set_title("Mean Image")
    ax2.imshow(np.random.binomial(1,np.exp(clf.feature_log_prob_[int(i)]),size=(784)).reshape(28,28), cmap="gray")
    ax2.set_title("Generated Sample")
    plt.show()

# %%
y_pred = clf.predict(X_test)

cfm = np.array(confusion_matrix(y_test,y_pred))
df_cm = pd.DataFrame(cfm, range(10),
                  range(10))
plt.figure(figsize = (18,8))
sns.set(font_scale=1.2)#for label size
ax = sns.heatmap(df_cm, annot=True, annot_kws={"size": 12})
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5);

#To calculate accuracy:
diagonal_sum = cfm.trace()
sum_of_all_elements = cfm.sum()
print("The accuracy of our confusion matrix is: ", diagonal_sum / sum_of_all_elements)

for i in range(0,10):
    acc_i = np.round(cfm[i,i]/sum(cfm[i,:]),4)
    print("The accuracy for label {} is {}".format(i, acc_i))
# Out:
# The accuracy of our confusion matrix is:  0.8413
# The accuracy for label 0 is 0.9051
# The accuracy for label 1 is 0.9559
# The accuracy for label 2 is 0.8256
# The accuracy for label 3 is 0.8356
# The accuracy for label 4 is 0.8096
# The accuracy for label 5 is 0.7029
# The accuracy for label 6 is 0.8883
# The accuracy for label 7 is 0.8473
# The accuracy for label 8 is 0.7782
# The accuracy for label 9 is 0.8355

# %% [markdown]
# Interestingly, comparing this confusion matrix to the one generated with Logistic Regression, although this model performs worse (.83 accuracy as opposed to .92), they both struggle with the same type of mistakes(ex: 3 for 5), although not exactly. Because this model works pixel by pixel, it struggles most when the two numbers have a lot of overlap on a pixel level.
# Nevertheless, a .83 accuracy is still pretty decent.

# %% [markdown]
# **Q: Think of a way you can find the optimal threshold of the binarization part.<br>A:**
# The logic is that at both threshold = 0.0 and 364, they are either overfitting or underfitting, so the solution will be in the middle. <br><br>
# As a hyperparameter, we can run CV and find it using Brute Force, but being that it could run from 0-365, we would like to use some heuristic to optimize the search.<br><br>
# If I can make the assumption that the graph of the optimal threshold will be a concave parabola, where the local optimum is the global optimum, as such we can easily implement some form of greedy recursive algorithm where we take 0 - LB and 365 - UB, and check both their values and MB = UB + LB /2, we then recursively check [UB,MB] and [MB,UB], if we get that MB < LB || MB < UB, we return max(LB,UB), repeat until convergence and return the final max(). For this to be true the sample size must be very large, so that the accuracy isnt dependent on the particular examples used for the train set.

# %%
accuracy = {}
for i in range(0, np.max(X_train), 10):
    labels = BernoulliNB(binarize=i).fit(X_train, y_train).predict(X_test)
    conf_matrix = np.array(confusion_matrix(y_test, labels))
    acc = np.trace(conf_matrix)/np.sum(conf_matrix) 
    print(f'Accuracy with binarize threshhold = {i}: {round(acc,3)*100}%')
    accuracy[i] = acc
# Out:
# Accuracy with binarize threshhold = 0: 84.1%
# Accuracy with binarize threshhold = 10: 84.3%
# Accuracy with binarize threshhold = 20: 84.3%
# Accuracy with binarize threshhold = 30: 84.39999999999999%
# Accuracy with binarize threshhold = 40: 84.5%
# Accuracy with binarize threshhold = 50: 84.39999999999999%
# Accuracy with binarize threshhold = 60: 84.39999999999999%
# Accuracy with binarize threshhold = 70: 84.39999999999999%
# Accuracy with binarize threshhold = 80: 84.39999999999999%
# Accuracy with binarize threshhold = 90: 84.39999999999999%
# Accuracy with binarize threshhold = 100: 84.39999999999999%
# Accuracy with binarize threshhold = 110: 84.6%
# Accuracy with binarize threshhold = 120: 84.39999999999999%
# Accuracy with binarize threshhold = 130: 84.3%
# Accuracy with binarize threshhold = 140: 84.39999999999999%
# Accuracy with binarize threshhold = 150: 84.3%
# Accuracy with binarize threshhold = 160: 84.3%
# Accuracy with binarize threshhold = 170: 84.1%
# Accuracy with binarize threshhold = 180: 84.0%
# Accuracy with binarize threshhold = 190: 83.89999999999999%
# Accuracy with binarize threshhold = 200: 83.5%
# Accuracy with binarize threshhold = 210: 83.1%
# Accuracy with binarize threshhold = 220: 82.5%
# Accuracy with binarize threshhold = 230: 82.19999999999999%
# Accuracy with binarize threshhold = 240: 81.3%
# Accuracy with binarize threshhold = 250: 79.80000000000001%

# %%
plt.plot(list(accuracy.keys()), list(accuracy.values()))

# %% [markdown]
# ## 2. Classifing Text Documents using Multinomial Naive Bayes
# In this exercise you will classify the "20 newsgroups" data set using your own naive bayes classifier and compare to the scikit learn built in version.
#
# The 20 newsgroups dataset comprises around 18000 newsgroups posts on 20 topics split in two subsets: one for training (or development) and the other one for testing (or for performance evaluation). The split between the train and test set is based upon messages posted before and after a specific date.
#
#
# * Load the **train** data using `from sklearn.datasets import fetch_20newsgroups`. remove headers, footers and quotes (see documentation)
# * Use `sklearn.feature_extraction.text import CountVectorizer` to count words (stop_words='english')
# * Write a class `NaiveBayes(BaseEstimator, ClassifierMixin)` and implement its `fit`, `predict` and `predict_proba` methods.
# * use `sklearn.pipeline.make_pipeline` to chain the vectroizer and model.
# * note: limit the vocuabolary size if you suffer memory issues
# * compare the accuracy over the **test** data. You can use `accuracy_score, classification_report`
# * compare to the built in `sklearn.naive_bayes.MultinomialNB`
# * compare to `TfidfVectorizer` preprocessing (you can use the built in model for doing the analysis)
# * plot the learning curve - is the model in the bias or variance regime (you can use the built in model for doing the analysis)
# * optimize performance in respect to vectorizer hyper parameters (e.g. max_features, max_df etc.).
#
# ### Optional: Model interpretability
# Find the most important features for a **specific** decision of a NB classifier.
# Because the model has learned the prior $p(x_i|c)$ during the training, the contribution of an individual feature value can be easily measured by the posterior, $p(c|x_i)=p(c)p(x_i|c)/p(x_i)$
# Implement a function which gets a scikit-learn NB model as input and returns $P(c|x_i)$:
#
# `def calc_p_c_given_xi(model)`
#
# Hint: Use the following model properties:
#
# * `model.class_log_prior_`
# * `model.feature_log_prob_`
#
# Note: remember these are logs and you need to use np.exp and normalize to get $P(c|x_i)$
# Another hint: use numpy built-in broadcasting property.
#
# * Use the interpretation to examine errors of the classifier where $\hat{c}\ne c$. Which top words support the correct class and which support the wrong class? You can use the `print_txt` below to color words.
#
# Bonus: How can you correct the analyzed error?
#
# To read more about model interpretation, see the blogpost below and my tutorial:
# * https://lilianweng.github.io/lil-log/2017/08/01/how-to-explain-the-prediction-of-a-machine-learning-model.html
# * https://github.com/chanansh/right_but_why

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, ShuffleSplit, learning_curve
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from sklearn.base import BaseEstimator, ClassifierMixin
from time import time
from spacy.lang.en.stop_words import STOP_WORDS as en_stop

# %%
class NaiveBayes(BaseEstimator, ClassifierMixin):
    def fit(self, x, y):
        self.N_docs = y.size
        self.classes, self.class_sizes = np.unique(y, return_counts=True,)
        self.class_priors = self.class_sizes/self.N_docs
        self.class_log_prior_ = np.log(self.class_priors)
        self.class_vectors = np.array([x[y == p] for p in self.classes])
        self.term_freq_ = np.sum(x, axis=0) + x.shape[1]
        self.class_term_freq_ = np.array([np.sum(class_vector.toarray(), axis=0) + 1 
                                              for class_vector in self.class_vectors])
        self.feature_term_prob_ = self.class_term_freq_/self.term_freq_
        self.feature_log_prob_ = np.log(self.feature_term_prob_).copy()
    def predict_log_proba(self, x):
        return self.class_log_prior_ + np.array(x * self.feature_log_prob.T)
    def predict(self, x):
        return np.argmax(self.class_log_prior_ + np.array(x * self.feature_log_prob_.T), axis=1)

# %%
random_state = 42
shuffle = True
remove = ['headers', 'footers', 'quotes']
data_dict = {}
for subset in ["train", "test"]:
    data = fetch_20newsgroups(subset=subset,
                            shuffle=shuffle, 
                            random_state=random_state,
                            remove=remove)
    data_dict[subset] = data
    n = len(data.data)
    print("{} - {} documents".format(subset, n))
X_train, y_train = data_dict['train'].data, data_dict['train'].target
X_test, y_test = data_dict['test'].data, data_dict['test'].target
target_names = data_dict['train'].target_names
en_stop = list(en_stop)
# Out:
# train - 11314 documents
# test - 7532 documents

# %%
vectorizer = CountVectorizer(stop_words='english')
tfidfvectorizer = TfidfVectorizer(stop_words='english')
max_df = 0.25

# %%
model1 = NaiveBayes()
pipe1 = make_pipeline(vectorizer, model1)
pipe1.fit(X_train, y_train)
pipe_preds1 = pipe1.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, pipe_preds1)}')
conf_matrix1 = pd.DataFrame(confusion_matrix(y_true=y_test, y_pred=pipe_preds1), index=target_names)
conf_matrix1.columns = target_names
conf_matrix1
# Out:
# Accuracy: 0.5622676579925651
#                           alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# alt.atheism                        38              0                        0
# comp.graphics                       0            218                        4
# comp.os.ms-windows.misc             2             21                       70
# comp.sys.ibm.pc.hardware            0             17                        9
# comp.sys.mac.hardware               0             15                        9
# comp.windows.x                      0             16                        2
# misc.forsale                        0              3                        1
# rec.autos                           0              2                        4
# rec.motorcycles                     1              1                        1
# rec.sport.baseball                  1              1                        0
# rec.sport.hockey                    0              0                        0
# sci.crypt                           0              3                        0
# sci.electronics                     0             10                        2
# sci.med                             0              5                        1
# sci.space                           0              6                        0
# soc.religion.christian              2              2                        0
# talk.politics.guns                  0              0                        1
# talk.politics.mideast               0              0                        0
# talk.politics.misc                  2              0                        0
# talk.religion.misc                  9              0                        1
#
#                           comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  \
# alt.atheism                                      1                      0
# comp.graphics                                    9                      2
# comp.os.ms-windows.misc                         50                      5
# comp.sys.ibm.pc.hardware                       234                      9
# comp.sys.mac.hardware                           44                    151
# comp.windows.x                                   2                      0
# misc.forsale                                    38                      8
# rec.autos                                        1                      1
# rec.motorcycles                                  1                      0
# rec.sport.baseball                               0                      0
# rec.sport.hockey                                 0                      0
# sci.crypt                                        0                      0
# sci.electronics                                 15                      2
# sci.med                                          0                      0
# sci.space                                        0                      0
# soc.religion.christian                           0                      0
# talk.politics.guns                               0                      0
# talk.politics.mideast                            0                      0
# talk.politics.misc                               0                      0
# talk.religion.misc                               0                      0
#
#                           comp.windows.x  misc.forsale  rec.autos  \
# alt.atheism                            3             0          0
# comp.graphics                         70             2          0
# comp.os.ms-windows.misc              159             1          1
# comp.sys.ibm.pc.hardware              42             5          0
# comp.sys.mac.hardware                 43             7          0
# comp.windows.x                       335             0          1
# misc.forsale                          15           240          6
# rec.autos                             11             8        204
# rec.motorcycles                        7             5         14
# rec.sport.baseball                     9             0          0
# rec.sport.hockey                       1             0          1
# sci.crypt                              4             0          0
# sci.electronics                       26             6          2
# sci.med                                2             0          2
# sci.space                              5             0          1
# soc.religion.christian                 2             0          0
# talk.politics.guns                     2             1          0
# talk.politics.mideast                  3             0          0
# talk.politics.misc                     2             0          0
# talk.religion.misc                     3             0          0
#
#                           rec.motorcycles  rec.sport.baseball  \
# alt.atheism                             2                   0
# comp.graphics                           0                   0
# comp.os.ms-windows.misc                 0                   0
# comp.sys.ibm.pc.hardware                0                   0
# comp.sys.mac.hardware                   0                   0
# comp.windows.x                          0                   0
# misc.forsale                            0                   0
# rec.autos                               7                   0
# rec.motorcycles                       169                   1
# rec.sport.baseball                      1                 220
# rec.sport.hockey                        0                   0
# sci.crypt                               0                   0
# sci.electronics                         0                   0
# sci.med                                 0                   0
# sci.space                               0                   0
# soc.religion.christian                  0                   0
# talk.politics.guns                      0                   0
# talk.politics.mideast                   0                   1
# talk.politics.misc                      0                   0
# talk.religion.misc                      0                   0
#
#                           rec.sport.hockey  sci.crypt  sci.electronics  \
# alt.atheism                             13         17                0
# comp.graphics                            7         51                0
# comp.os.ms-windows.misc                 16         48                1
# comp.sys.ibm.pc.hardware                 7         47               14
# comp.sys.mac.hardware                   15         59                8
# comp.windows.x                           8         17                1
# misc.forsale                            12         23                4
# rec.autos                               31         32                3
# rec.motorcycles                         17         38                9
# rec.sport.baseball                      66         16                1
# rec.sport.hockey                       359          9                0
# sci.crypt                               18        327                1
# sci.electronics                         15        132              119
# sci.med                                 15         11                1
# sci.space                               18         20                2
# soc.religion.christian                  16          5                0
# talk.politics.guns                      12         34                0
# talk.politics.mideast                    6          9                0
# talk.politics.misc                       8         20                1
# talk.religion.misc                       8         12                0
#
#                           sci.med  sci.space  soc.religion.christian  \
# alt.atheism                     5         10                     160
# comp.graphics                   2          9                       5
# comp.os.ms-windows.misc         2          6                       4
# comp.sys.ibm.pc.hardware        1          2                       1
# comp.sys.mac.hardware           9         12                       2
# comp.windows.x                  1          6                       2
# misc.forsale                    4         10                       3
# rec.autos                       3         21                       9
# rec.motorcycles                 4         13                      19
# rec.sport.baseball              6          4                      19
# rec.sport.hockey                1          1                       6
# sci.crypt                       3          5                       3
# sci.electronics                11         27                       4
# sci.med                       290          9                      19
# sci.space                       6        292                       6
# soc.religion.christian          1          2                     347
# talk.politics.guns              0          3                      18
# talk.politics.mideast           0          0                      14
# talk.politics.misc              3          9                      14
# talk.religion.misc              4          7                     141
#
#                           talk.politics.guns  talk.politics.mideast  \
# alt.atheism                                4                     60
# comp.graphics                              0                      8
# comp.os.ms-windows.misc                    0                      4
# comp.sys.ibm.pc.hardware                   0                      3
# comp.sys.mac.hardware                      0                     11
# comp.windows.x                             0                      3
# misc.forsale                               1                     20
# rec.autos                                  7                     38
# rec.motorcycles                            8                     78
# rec.sport.baseball                         2                     42
# rec.sport.hockey                           1                     18
# sci.crypt                                  6                     24
# sci.electronics                            2                     19
# sci.med                                    4                     29
# sci.space                                  0                     30
# soc.religion.christian                     1                     19
# talk.politics.guns                       173                    107
# talk.politics.mideast                      4                    332
# talk.politics.misc                        53                     85
# talk.religion.misc                        14                     43
#
#                           talk.politics.misc  talk.religion.misc
# alt.atheism                                5                   1
# comp.graphics                              2                   0
# comp.os.ms-windows.misc                    4                   0
# comp.sys.ibm.pc.hardware                   1                   0
# comp.sys.mac.hardware                      0                   0
# comp.windows.x                             1                   0
# misc.forsale                               2                   0
# rec.autos                                 14                   0
# rec.motorcycles                           12                   0
# rec.sport.baseball                         9                   0
# rec.sport.hockey                           2                   0
# sci.crypt                                  2                   0
# sci.electronics                            1                   0
# sci.med                                    8                   0
# sci.space                                  8                   0
# soc.religion.christian                     1                   0
# talk.politics.guns                        12                   1
# talk.politics.mideast                      7                   0
# talk.politics.misc                       113                   0
# talk.religion.misc                         5                   4

# %%
model2 = MultinomialNB()
pipe2 = make_pipeline(vectorizer, model2)
pipe2.fit(X_train, y_train)
pipe_preds2 = pipe2.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, pipe_preds2)}')
conf_matrix2 = pd.DataFrame(confusion_matrix(y_true=y_test, y_pred=pipe_preds2), index=target_names)
conf_matrix2.columns = target_names
conf_matrix2
# Out:
# Accuracy: 0.6343600637280935
#                           alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# alt.atheism                        97              1                        0
# comp.graphics                       1            269                        0
# comp.os.ms-windows.misc             3             66                        2
# comp.sys.ibm.pc.hardware            0             13                        0
# comp.sys.mac.hardware               1             20                        1
# comp.windows.x                      0             32                        1
# misc.forsale                        0              5                        0
# rec.autos                           0              2                        0
# rec.motorcycles                     2              2                        0
# rec.sport.baseball                  0              3                        0
# rec.sport.hockey                    1              1                        0
# sci.crypt                           0              6                        0
# sci.electronics                     1             19                        1
# sci.med                             4              6                        0
# sci.space                           0             11                        0
# soc.religion.christian              3              4                        0
# talk.politics.guns                  2              0                        0
# talk.politics.mideast               2              0                        0
# talk.politics.misc                  9              0                        0
# talk.religion.misc                 23              0                        0
#
#                           comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  \
# alt.atheism                                      1                      0
# comp.graphics                                   14                      7
# comp.os.ms-windows.misc                        106                     12
# comp.sys.ibm.pc.hardware                       281                     24
# comp.sys.mac.hardware                           47                    216
# comp.windows.x                                   6                      4
# misc.forsale                                    38                     16
# rec.autos                                        2                      1
# rec.motorcycles                                  1                      1
# rec.sport.baseball                               2                      0
# rec.sport.hockey                                 1                      0
# sci.crypt                                        2                      4
# sci.electronics                                 24                      8
# sci.med                                          1                      0
# sci.space                                        1                      0
# soc.religion.christian                           0                      0
# talk.politics.guns                               0                      0
# talk.politics.mideast                            2                      0
# talk.politics.misc                               0                      0
# talk.religion.misc                               2                      0
#
#                           comp.windows.x  misc.forsale  rec.autos  \
# alt.atheism                            3             0          1
# comp.graphics                         35             2          0
# comp.os.ms-windows.misc              131             2          2
# comp.sys.ibm.pc.hardware              20             6          0
# comp.sys.mac.hardware                 18             9          3
# comp.windows.x                       318             1          0
# misc.forsale                           4           268          6
# rec.autos                              3             9        278
# rec.motorcycles                        2             5         26
# rec.sport.baseball                     6             2          0
# rec.sport.hockey                       1             0          1
# sci.crypt                              3             0          1
# sci.electronics                       11             7          9
# sci.med                                1             0          5
# sci.space                              2             0          3
# soc.religion.christian                 2             0          0
# talk.politics.guns                     2             2          0
# talk.politics.mideast                  2             0          0
# talk.politics.misc                     1             1          1
# talk.religion.misc                     2             0          1
#
#                           rec.motorcycles  rec.sport.baseball  \
# alt.atheism                             2                   1
# comp.graphics                           0                   2
# comp.os.ms-windows.misc                 1                   0
# comp.sys.ibm.pc.hardware                0                   0
# comp.sys.mac.hardware                   1                   0
# comp.windows.x                          0                   0
# misc.forsale                            2                   2
# rec.autos                              10                   1
# rec.motorcycles                       245                   4
# rec.sport.baseball                      2                 294
# rec.sport.hockey                        0                   2
# sci.crypt                               0                   1
# sci.electronics                         3                   1
# sci.med                                 0                   1
# sci.space                               1                   0
# soc.religion.christian                  0                   1
# talk.politics.guns                      0                   1
# talk.politics.mideast                   1                   1
# talk.politics.misc                      1                   0
# talk.religion.misc                      0                   1
#
#                           rec.sport.hockey  sci.crypt  sci.electronics  \
# alt.atheism                             12          8                0
# comp.graphics                            7         26                3
# comp.os.ms-windows.misc                 15         32                1
# comp.sys.ibm.pc.hardware                 7         18               16
# comp.sys.mac.hardware                   15         19               13
# comp.windows.x                           8         11                1
# misc.forsale                            10          4                8
# rec.autos                               29          5                7
# rec.motorcycles                         15         10               13
# rec.sport.baseball                      34          7                1
# rec.sport.hockey                       362          5                0
# sci.crypt                               18        311                4
# sci.electronics                         13         63              191
# sci.med                                 15          3                3
# sci.space                               17         11                3
# soc.religion.christian                  15          2                0
# talk.politics.guns                      12         16                2
# talk.politics.mideast                    6          8                0
# talk.politics.misc                       8         12                2
# talk.religion.misc                       8          4                1
#
#                           sci.med  sci.space  soc.religion.christian  \
# alt.atheism                     4         11                     130
# comp.graphics                   5          7                       6
# comp.os.ms-windows.misc         4          4                       3
# comp.sys.ibm.pc.hardware        1          1                       1
# comp.sys.mac.hardware           8          8                       2
# comp.windows.x                  2          6                       3
# misc.forsale                    1         10                       5
# rec.autos                       2         10                       8
# rec.motorcycles                 2          3                      15
# rec.sport.baseball              5          3                      16
# rec.sport.hockey                1          2                       8
# sci.crypt                       2          8                       4
# sci.electronics                12         15                       6
# sci.med                       312          5                      17
# sci.space                       7        296                      10
# soc.religion.christian          1          3                     362
# talk.politics.guns              4          5                      25
# talk.politics.mideast           1          0                      23
# talk.politics.misc              5          9                      14
# talk.religion.misc              4          7                     132
#
#                           talk.politics.guns  talk.politics.mideast  \
# alt.atheism                                5                     26
# comp.graphics                              0                      3
# comp.os.ms-windows.misc                    0                      2
# comp.sys.ibm.pc.hardware                   1                      2
# comp.sys.mac.hardware                      0                      2
# comp.windows.x                             0                      1
# misc.forsale                               3                      5
# rec.autos                                 11                      8
# rec.motorcycles                           14                     19
# rec.sport.baseball                         2                      5
# rec.sport.hockey                           1                      8
# sci.crypt                                 12                     14
# sci.electronics                            3                      5
# sci.med                                    4                      9
# sci.space                                  1                     12
# soc.religion.christian                     2                      2
# talk.politics.guns                       222                     45
# talk.politics.mideast                      9                    302
# talk.politics.misc                        77                     31
# talk.religion.misc                        25                     18
#
#                           talk.politics.misc  talk.religion.misc
# alt.atheism                               11                   6
# comp.graphics                              2                   0
# comp.os.ms-windows.misc                    7                   1
# comp.sys.ibm.pc.hardware                   1                   0
# comp.sys.mac.hardware                      2                   0
# comp.windows.x                             1                   0
# misc.forsale                               3                   0
# rec.autos                                 10                   0
# rec.motorcycles                           19                   0
# rec.sport.baseball                        15                   0
# rec.sport.hockey                           5                   0
# sci.crypt                                  6                   0
# sci.electronics                            1                   0
# sci.med                                   10                   0
# sci.space                                 19                   0
# soc.religion.christian                     1                   0
# talk.politics.guns                        23                   3
# talk.politics.mideast                     19                   0
# talk.politics.misc                       137                   2
# talk.religion.misc                         8                  15

# %% [markdown]
# As we can see, the built-in model performs better than our home-built model, although not to the degree that we were expecting

# %%
model3 = NaiveBayes()
pipe3 = make_pipeline(tfidfvectorizer, model3)
pipe3.fit(X_train, y_train)
pipe_preds3 = pipe3.predict(X_test)
print(f'Accuracy: {round(accuracy_score(y_test, pipe_preds3), 3) * 100}%')
conf_matrix3 = pd.DataFrame(confusion_matrix(y_true=y_test, y_pred=pipe_preds3), index=target_names)
conf_matrix3.columns = target_names
conf_matrix3
# Out:
# Accuracy: 67.5%
#                           alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# alt.atheism                        52              1                        1
# comp.graphics                       0            266                       19
# comp.os.ms-windows.misc             1             25                      228
# comp.sys.ibm.pc.hardware            0              7                       31
# comp.sys.mac.hardware               0              6                       14
# comp.windows.x                      0             31                       19
# misc.forsale                        0              1                        3
# rec.autos                           0              0                        2
# rec.motorcycles                     0              3                        0
# rec.sport.baseball                  0              3                        1
# rec.sport.hockey                    0              1                        0
# sci.crypt                           0              6                        6
# sci.electronics                     0             12                        9
# sci.med                             0              9                        1
# sci.space                           0             10                        1
# soc.religion.christian              1              3                        2
# talk.politics.guns                  1              0                        1
# talk.politics.mideast               1              1                        2
# talk.politics.misc                  1              1                        1
# talk.religion.misc                  7              5                        1
#
#                           comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  \
# alt.atheism                                      1                      1
# comp.graphics                                   12                     10
# comp.os.ms-windows.misc                         52                      8
# comp.sys.ibm.pc.hardware                       289                     21
# comp.sys.mac.hardware                           44                    256
# comp.windows.x                                   8                      2
# misc.forsale                                    34                     13
# rec.autos                                        3                      1
# rec.motorcycles                                  0                      2
# rec.sport.baseball                               0                      0
# rec.sport.hockey                                 0                      1
# sci.crypt                                        3                      2
# sci.electronics                                 33                     10
# sci.med                                          1                      1
# sci.space                                        1                      1
# soc.religion.christian                           0                      0
# talk.politics.guns                               0                      0
# talk.politics.mideast                            2                      0
# talk.politics.misc                               0                      1
# talk.religion.misc                               0                      0
#
#                           comp.windows.x  misc.forsale  rec.autos  \
# alt.atheism                            2             0          0
# comp.graphics                         26             6          0
# comp.os.ms-windows.misc               18             4          2
# comp.sys.ibm.pc.hardware               2             7          0
# comp.sys.mac.hardware                  4             9          3
# comp.windows.x                       302             3          0
# misc.forsale                           0           296          9
# rec.autos                              1            12        289
# rec.motorcycles                        2             7         16
# rec.sport.baseball                     3             6          0
# rec.sport.hockey                       0             0          1
# sci.crypt                              4             3          0
# sci.electronics                        2            15          9
# sci.med                                1             3          3
# sci.space                              0             4          2
# soc.religion.christian                 0             0          0
# talk.politics.guns                     1             1          1
# talk.politics.mideast                  1             0          1
# talk.politics.misc                     2             0          4
# talk.religion.misc                     0             1          3
#
#                           rec.motorcycles  rec.sport.baseball  \
# alt.atheism                             2                   4
# comp.graphics                           3                   0
# comp.os.ms-windows.misc                 2                   0
# comp.sys.ibm.pc.hardware                0                   0
# comp.sys.mac.hardware                   1                   0
# comp.windows.x                          0                   1
# misc.forsale                            2                   1
# rec.autos                              12                   1
# rec.motorcycles                       293                   3
# rec.sport.baseball                      2                 317
# rec.sport.hockey                        0                   3
# sci.crypt                               2                   2
# sci.electronics                         6                   1
# sci.med                                 0                   2
# sci.space                               1                   2
# soc.religion.christian                  0                   1
# talk.politics.guns                      3                   0
# talk.politics.mideast                   4                   3
# talk.politics.misc                      1                   1
# talk.religion.misc                      0                   1
#
#                           rec.sport.hockey  sci.crypt  sci.electronics  \
# alt.atheism                             14          9                1
# comp.graphics                            7         17                1
# comp.os.ms-windows.misc                 16         18                0
# comp.sys.ibm.pc.hardware                 8          9               15
# comp.sys.mac.hardware                   15         12               11
# comp.windows.x                           8         12                2
# misc.forsale                            11          3                6
# rec.autos                               28          8               10
# rec.motorcycles                         14         10               12
# rec.sport.baseball                      38          3                1
# rec.sport.hockey                       373          4                0
# sci.crypt                               17        315                4
# sci.electronics                         11         54              207
# sci.med                                 18          6                5
# sci.space                               20         14                6
# soc.religion.christian                  14          2                0
# talk.politics.guns                      13         32                1
# talk.politics.mideast                    7          5                0
# talk.politics.misc                      11         26                3
# talk.religion.misc                       9          5                1
#
#                           sci.med  sci.space  soc.religion.christian  \
# alt.atheism                     3          9                     193
# comp.graphics                   0         12                       9
# comp.os.ms-windows.misc         1          8                      11
# comp.sys.ibm.pc.hardware        0          0                       2
# comp.sys.mac.hardware           1          3                       5
# comp.windows.x                  0          2                       4
# misc.forsale                    0          2                       6
# rec.autos                       4          7                       8
# rec.motorcycles                 3          7                      18
# rec.sport.baseball              2          0                      20
# rec.sport.hockey                1          1                      11
# sci.crypt                       0          5                       9
# sci.electronics                 7          8                       6
# sci.med                       300          4                      35
# sci.space                       4        294                      22
# soc.religion.christian          1          3                     370
# talk.politics.guns              1          4                      38
# talk.politics.mideast           2          0                      39
# talk.politics.misc              3         10                      50
# talk.religion.misc              4          5                     172
#
#                           talk.politics.guns  talk.politics.mideast  \
# alt.atheism                                8                     18
# comp.graphics                              0                      1
# comp.os.ms-windows.misc                    0                      0
# comp.sys.ibm.pc.hardware                   1                      0
# comp.sys.mac.hardware                      1                      0
# comp.windows.x                             1                      0
# misc.forsale                               2                      1
# rec.autos                                  4                      4
# rec.motorcycles                            6                      2
# rec.sport.baseball                         1                      0
# rec.sport.hockey                           3                      0
# sci.crypt                                 12                      5
# sci.electronics                            2                      1
# sci.med                                    4                      2
# sci.space                                  6                      5
# soc.religion.christian                     1                      0
# talk.politics.guns                       256                      9
# talk.politics.mideast                      8                    298
# talk.politics.misc                        99                     14
# talk.religion.misc                        26                      9
#
#                           talk.politics.misc  talk.religion.misc
# alt.atheism                                0                   0
# comp.graphics                              0                   0
# comp.os.ms-windows.misc                    0                   0
# comp.sys.ibm.pc.hardware                   0                   0
# comp.sys.mac.hardware                      0                   0
# comp.windows.x                             0                   0
# misc.forsale                               0                   0
# rec.autos                                  2                   0
# rec.motorcycles                            0                   0
# rec.sport.baseball                         0                   0
# rec.sport.hockey                           0                   0
# sci.crypt                                  1                   0
# sci.electronics                            0                   0
# sci.med                                    1                   0
# sci.space                                  1                   0
# soc.religion.christian                     0                   0
# talk.politics.guns                         2                   0
# talk.politics.mideast                      2                   0
# talk.politics.misc                        82                   0
# talk.religion.misc                         0                   2

# %%
model4 = MultinomialNB()
pipe4 = make_pipeline(tfidfvectorizer, model4)
pipe4.fit(X_train, y_train)
pipe_preds4 = pipe4.predict(X_test)
print(f'Accuracy: {round(accuracy_score(y_test, pipe_preds4), 3) * 100}%')
conf_matrix4 = pd.DataFrame(confusion_matrix(y_true=y_test, y_pred=pipe_preds4), index=target_names)
conf_matrix4.columns = target_names
conf_matrix4
# Out:
# Accuracy: 67.80000000000001%
#                           alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# alt.atheism                        56              2                        2
# comp.graphics                       0            267                       18
# comp.os.ms-windows.misc             1             25                      230
# comp.sys.ibm.pc.hardware            0              7                       31
# comp.sys.mac.hardware               0              7                       14
# comp.windows.x                      0             33                       19
# misc.forsale                        0              1                        3
# rec.autos                           0              0                        2
# rec.motorcycles                     0              3                        0
# rec.sport.baseball                  0              3                        1
# rec.sport.hockey                    0              1                        0
# sci.crypt                           0              7                        6
# sci.electronics                     0             12                       11
# sci.med                             0             10                        1
# sci.space                           0             13                        1
# soc.religion.christian              1              3                        2
# talk.politics.guns                  2              0                        1
# talk.politics.mideast               1              1                        2
# talk.politics.misc                  2              1                        1
# talk.religion.misc                 11              5                        1
#
#                           comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  \
# alt.atheism                                      1                      1
# comp.graphics                                   12                     10
# comp.os.ms-windows.misc                         51                      9
# comp.sys.ibm.pc.hardware                       290                     21
# comp.sys.mac.hardware                           44                    257
# comp.windows.x                                   7                      4
# misc.forsale                                    34                     13
# rec.autos                                        3                      1
# rec.motorcycles                                  1                      2
# rec.sport.baseball                               0                      0
# rec.sport.hockey                                 0                      1
# sci.crypt                                        4                      2
# sci.electronics                                 34                     11
# sci.med                                          1                      1
# sci.space                                        1                      1
# soc.religion.christian                           0                      0
# talk.politics.guns                               0                      0
# talk.politics.mideast                            2                      0
# talk.politics.misc                               0                      1
# talk.religion.misc                               0                      0
#
#                           comp.windows.x  misc.forsale  rec.autos  \
# alt.atheism                            2             0          0
# comp.graphics                         26             6          0
# comp.os.ms-windows.misc               18             4          2
# comp.sys.ibm.pc.hardware               2             7          1
# comp.sys.mac.hardware                  3             9          3
# comp.windows.x                       303             3          0
# misc.forsale                           0           297          9
# rec.autos                              1            12        291
# rec.motorcycles                        2             7         16
# rec.sport.baseball                     3             6          0
# rec.sport.hockey                       0             0          1
# sci.crypt                              4             3          0
# sci.electronics                        2            15          9
# sci.med                                2             4          4
# sci.space                              0             4          3
# soc.religion.christian                 0             0          0
# talk.politics.guns                     1             1          1
# talk.politics.mideast                  1             0          1
# talk.politics.misc                     2             0          4
# talk.religion.misc                     0             1          3
#
#                           rec.motorcycles  rec.sport.baseball  \
# alt.atheism                             2                   4
# comp.graphics                           3                   0
# comp.os.ms-windows.misc                 2                   1
# comp.sys.ibm.pc.hardware                0                   0
# comp.sys.mac.hardware                   1                   0
# comp.windows.x                          0                   1
# misc.forsale                            2                   1
# rec.autos                              12                   1
# rec.motorcycles                       296                   4
# rec.sport.baseball                      2                 317
# rec.sport.hockey                        0                   3
# sci.crypt                               3                   2
# sci.electronics                         6                   1
# sci.med                                 1                   2
# sci.space                               1                   2
# soc.religion.christian                  0                   1
# talk.politics.guns                      3                   0
# talk.politics.mideast                   4                   3
# talk.politics.misc                      1                   1
# talk.religion.misc                      0                   1
#
#                           rec.sport.hockey  sci.crypt  sci.electronics  \
# alt.atheism                             14          8                1
# comp.graphics                            7         17                1
# comp.os.ms-windows.misc                 16         17                0
# comp.sys.ibm.pc.hardware                 8          7               15
# comp.sys.mac.hardware                   15         11               11
# comp.windows.x                           8          8                2
# misc.forsale                            11          3                6
# rec.autos                               27          6               11
# rec.motorcycles                         14          7               12
# rec.sport.baseball                      38          3                1
# rec.sport.hockey                       373          4                0
# sci.crypt                               17        313                4
# sci.electronics                         11         51              206
# sci.med                                 18          6                5
# sci.space                               20         10                6
# soc.religion.christian                  14          2                1
# talk.politics.guns                      13         31                1
# talk.politics.mideast                    7          5                1
# talk.politics.misc                      11         22                3
# talk.religion.misc                       9          4                1
#
#                           sci.med  sci.space  soc.religion.christian  \
# alt.atheism                     3          9                     188
# comp.graphics                   0         12                       9
# comp.os.ms-windows.misc         1          8                       9
# comp.sys.ibm.pc.hardware        0          0                       2
# comp.sys.mac.hardware           1          3                       5
# comp.windows.x                  0          2                       4
# misc.forsale                    0          2                       5
# rec.autos                       4          7                       8
# rec.motorcycles                 3          7                      15
# rec.sport.baseball              2          0                      20
# rec.sport.hockey                1          1                      11
# sci.crypt                       0          5                       9
# sci.electronics                 7          8                       6
# sci.med                       301          3                      29
# sci.space                       5        293                      20
# soc.religion.christian          1          3                     369
# talk.politics.guns              1          4                      35
# talk.politics.mideast           2          0                      37
# talk.politics.misc              3         10                      45
# talk.religion.misc              4          5                     167
#
#                           talk.politics.guns  talk.politics.mideast  \
# alt.atheism                                8                     18
# comp.graphics                              0                      1
# comp.os.ms-windows.misc                    0                      0
# comp.sys.ibm.pc.hardware                   1                      0
# comp.sys.mac.hardware                      1                      0
# comp.windows.x                             1                      0
# misc.forsale                               2                      1
# rec.autos                                  4                      4
# rec.motorcycles                            6                      2
# rec.sport.baseball                         1                      0
# rec.sport.hockey                           3                      0
# sci.crypt                                 12                      4
# sci.electronics                            2                      1
# sci.med                                    5                      2
# sci.space                                  7                      5
# soc.religion.christian                     1                      0
# talk.politics.guns                       259                      9
# talk.politics.mideast                      9                    298
# talk.politics.misc                       102                     13
# talk.religion.misc                        28                      9
#
#                           talk.politics.misc  talk.religion.misc
# alt.atheism                                0                   0
# comp.graphics                              0                   0
# comp.os.ms-windows.misc                    0                   0
# comp.sys.ibm.pc.hardware                   0                   0
# comp.sys.mac.hardware                      0                   0
# comp.windows.x                             0                   0
# misc.forsale                               0                   0
# rec.autos                                  2                   0
# rec.motorcycles                            1                   0
# rec.sport.baseball                         0                   0
# rec.sport.hockey                           0                   0
# sci.crypt                                  1                   0
# sci.electronics                            0                   0
# sci.med                                    1                   0
# sci.space                                  2                   0
# soc.religion.christian                     0                   0
# talk.politics.guns                         2                   0
# talk.politics.mideast                      2                   0
# talk.politics.misc                        88                   0
# talk.religion.misc                         0                   2

# %% [markdown]
# When we vectorize our data using TFIDF the two models perform almost exactly the same. However, performance by class varies significantly, with class 19 having an F1 score of 2% and class 9 having an F1 score of 85%.

# %%
#%%
title = "Learning Curves (Naive Bayes)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=3, test_size=0.2, random_state=0)
estimator = NaiveBayes()
train_sizes=np.linspace(.1, 1.0, 5)
plt.title("Learning curves for Naive Bayes")
plt.xlabel("Training examples")
plt.ylabel("Score")
train_sizes, train_scores, test_scores, fit_times, _ = \
    learning_curve(pipe3, X_train, y_train, cv=cv,
                   train_sizes=train_sizes,
                   return_times=True)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)
fit_times_mean = np.mean(fit_times, axis=1)
fit_times_std = np.std(fit_times, axis=1)
# Plot learning curve
plt.grid()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1,
                     color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")
plt.legend(loc="best");
#%%

# %%
#%%
title = "Learning Curves (Naive Bayes)"
# Cross validation with 100 iterations to get smoother mean test and train
# score curves, each time with 20% data randomly selected as a validation set.
cv = ShuffleSplit(n_splits=3, test_size=0.2, random_state=0)
estimator = MultinomialNB()
train_sizes=np.linspace(.1, 1.0, 5)
plt.title("Learning curves for Scikit Learn Naive Bayes")
plt.xlabel("Training examples")
plt.ylabel("Score")
train_sizes, train_scores, test_scores, fit_times, _ = \
    learning_curve(pipe4, X_train, y_train, cv=cv,
                   train_sizes=train_sizes,
                   return_times=True)
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)
test_scores_std = np.std(test_scores, axis=1)
fit_times_mean = np.mean(fit_times, axis=1)
fit_times_std = np.std(fit_times, axis=1)
# Plot learning curve
plt.grid()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1,
                     color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")
plt.legend(loc="best");
#%%

# %% [markdown]
# We can see that the model is low bias since it performs well on the training set, but it doesn't generalize well meaning it has high variance. However, we do see that the Training and CV scores converge as we add training examples, menaing that this algorithm would benefit from more data.

# %%
parameters = {
    'tfidfvectorizer__max_df': (0.25, 0.5, 0.75, 1.0),
    'tfidfvectorizer__max_features': (None, 10000, 50000),
}
t0 = time()
grid_search = GridSearchCV(pipe, parameters, verbose=1)
grid_search.fit(x_train, y_train)
print("done in %0.3fs" % (time() - t0))
print()
print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f031aa90440f> in <module>
#       4 }
#       5 t0 = time()
# ----> 6 grid_search = GridSearchCV(pipe, parameters, verbose=1)
#       7 grid_search.fit(x_train, y_train)
#       8 print("done in %0.3fs" % (time() - t0))
#
# NameError: name 'pipe' is not defined

# %% [markdown]
# After running the GridSearch CV with Multinomial NB we found the parameters above, however running the model with said parameters doesn't actually improve the performance over the default settings by any measurable margin

# %%
def calc_p_c_given_xi(model):
    p_c = np.exp(model.class_log_prior_)
    p_w_c = np.exp(model.feature_log_prob_)
    p_c_w = p_c.reshape(-1,1) * p_w_c
    p_c_w = p_c_w/p_c_w.sum(axis=0)
    return p_c_w
p_c_w = calc_p_c_given_xi(model4)

# %%
x = vectorizer.transform(X_test)
idx2word={v:k for k, v in vectorizer.vocabulary_.items()}
cold_color='\x1b[41;37m{}\x1b[0m'
hot_color='\x1b[42;37m{}\x1b[0m'
mid_color='\x1b[45;37m{}\x1b[0m' 
def word_by_score(c, word_index, min_p=0.1, max_n=10):
    """
    return a pandas series with index being the word and its index and the value being p(c|xi)
    """
    word_score = p_c_w[c, word_index]
    words =[idx2word[w] for w in word_index]
    s = pd.Series(word_score.flatten(), index=[words, word_index])
    s.index.names=['word','idx']
    s.name = 'score'
    stop = s.sort_values(ascending=False)
    stop = stop[stop>min_p]
    if len(stop)>max_n:
        stop = stop[:max_n]
    return stop.reset_index()

# %%
import string
def print_txt(txt, hot, cold):
    """
    print the text, coloring hot and cold words with colors
    """
    def color(token):
        lower = str(token).lower()
        lower = lower.replace('\t','').replace('\n','')
        lower = lower.translate(string.punctuation)
        if (lower in hot) and (lower in cold):
            return mid_color.format(token)
        elif lower in hot:
            return hot_color.format(token)
        elif lower in cold:
            return cold_color.format(token)
        else:
            return token
    colored_txt = " ".join([color(token) for token in txt.split(' ')])
    print(colored_txt)

# %%
def display_doc(i, pred):
    """
    displaying document i
    """
    c_hat = pred[i]
    c = y_test[i]
    txt = X_test[i]
    xi = x[i,:]
    nz = xi.nonzero()[1] # non zero words

    print('')
    print('document={}, c={} ({}), guess correctly = {}'.format(i, c, target_names[c], c_hat==c))
    print('-'*80)
    hot = word_by_score(c,nz)
    print(hot)
    hot_words = hot.word.tolist()
    if c_hat!=c:
        print('-'*80)
        print('score for incorrect guess c_hat={} ({})'.format(c_hat, target_names[c_hat]))
        print('-'*80)
        cold = word_by_score(c_hat,nz)
        cold_words = cold.word.tolist()
        print(cold)
    else:
        cold_words = []
    print('-'*80)
    print('text:')
    print('-'*80)
    print_txt(txt, hot_words, cold_words)

# %%
i = 345
display_doc(i, pipe_preds2)
